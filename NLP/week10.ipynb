# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# Sample text
text = "This is a sample sentence to demonstrate PoS tagging."

# Tokenize the text into words
words = word_tokenize(text)

# Perform PoS tagging
pos_tags = pos_tag(words)

# Display the PoS tags
print(pos_tags)
# Out:
# [('This', 'DT'), ('is', 'VBZ'), ('a', 'DT'), ('sample', 'JJ'), ('sentence', 'NN'), ('to', 'TO'), ('demonstrate', 'VB'), ('PoS', 'NNP'), ('tagging', 'NN'), ('.', '.')]

# %%
import nltk

def find_word_with_most_tags():
    # Load the Brown corpus
    nltk.download('brown')
    corpus = nltk.corpus.brown.tagged_words()

    # Create a dictionary to store the tags for each word
    word_tags = {}

    # Iterate through the tagged words and populate the dictionary
    for word, tag in corpus:
        if word not in word_tags:
            word_tags[word] = set()
        word_tags[word].add(tag)

    # Find the word with the most distinct tags
    max_tags_word = max(word_tags, key=lambda word: len(word_tags[word]))
    max_tags_count = len(word_tags[max_tags_word])
    max_tags = word_tags[max_tags_word]

    return max_tags_word, max_tags_count, max_tags

# Find the word with the most distinct tags
word, count, tags = find_word_with_most_tags()

# Print the result
print(f"The word '{word}' has the greatest number of distinct tags, which are: {tags}")
print(f"It has {count} distinct tags.")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# The word 'that' has the greatest number of distinct tags, which are: {'WPS', 'QL', 'CS-HL', 'DT', 'NIL', 'WPO-NC', 'WPS-HL', 'WPO', 'CS', 'WPS-NC', 'DT-NC', 'CS-NC'}
# It has 12 distinct tags.

# %%
import nltk
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package tagsets to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping help\tagsets.zip.
# True

# %%
import nltk

def list_tags_in_decreasing_frequency():
    # Load the Brown corpus
    nltk.download('brown')
    corpus = nltk.corpus.brown.tagged_words()

    # Calculate frequency distribution of tags
    tag_freq_dist = nltk.FreqDist(tag for (word, tag) in corpus)

    # List tags in decreasing frequency
    tags_in_decreasing_frequency = tag_freq_dist.most_common()

    return tags_in_decreasing_frequency

# Get the list of tags in decreasing frequency
tags_in_decreasing_frequency = list_tags_in_decreasing_frequency()

# Print the 20 most frequent tags and their meanings
print("20 most frequent tags and their meanings:")
for tag, frequency in tags_in_decreasing_frequency[:20]:
    print(f"Tag: {tag}, Frequency: {frequency}")
    nltk.help.upenn_tagset(tag)
    print()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# 20 most frequent tags and their meanings:
# Tag: NN, Frequency: 152470
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
#
# Tag: IN, Frequency: 120557
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
#
# Tag: AT, Frequency: 97959
# No matching tags found.
#
# Tag: JJ, Frequency: 64028
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
#
# Tag: ., Frequency: 60638
# .: sentence terminator
#     . ! ?
#
# Tag: ,, Frequency: 58156
# ,: comma
#     ,
#
# Tag: NNS, Frequency: 55110
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
#
# Tag: CC, Frequency: 37718
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
#
# Tag: RB, Frequency: 36464
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
#
# Tag: NP, Frequency: 34476
# No matching tags found.
#
# Tag: VB, Frequency: 33693
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
#
# Tag: VBN, Frequency: 29186
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
#
# Tag: VBD, Frequency: 26167
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
#
# Tag: CS, Frequency: 22143
# No matching tags found.
#
# Tag: PPS, Frequency: 18253
# No matching tags found.
#
# Tag: VBG, Frequency: 17893
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
#
# Tag: PP$, Frequency: 16872
# No matching tags found.
#
# Tag: TO, Frequency: 14918
# TO: "to" as preposition or infinitive marker
#     to
#
# Tag: PPSS, Frequency: 13802
# No matching tags found.
#
# Tag: CD, Frequency: 13510
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...

# %%
import nltk
import re

def is_valid_tag(tag):
    # Regular expression to match valid tags (uppercase letters and symbols)
    return re.match(r'^[A-Z$-]+$', tag) is not None

def find_nouns_following_tags():
    # Load the Brown corpus
    nltk.download('brown')
    corpus = nltk.corpus.brown.tagged_words()

    # Create a dictionary to store nouns following tags
    nouns_following_tags = {}

    # Iterate over the tagged words in the corpus
    for i in range(len(corpus) - 1):
        # Check if the current word is a noun
        if corpus[i][1].startswith('N'):
            # Get the tag of the following word
            following_tag = corpus[i+1][1]
            # Add the following tag to the dictionary if it's valid
            if is_valid_tag(following_tag):
                if following_tag not in nouns_following_tags:
                    nouns_following_tags[following_tag] = 1
                else:
                    nouns_following_tags[following_tag] += 1

    return nouns_following_tags

# Get the nouns following tags
nouns_following_tags = find_nouns_following_tags()

# Sort the dictionary by frequency
sorted_nouns_following_tags = {k: v for k, v in sorted(nouns_following_tags.items(), key=lambda item: item[1], reverse=True)}

# Print the results
print("Tags most commonly found after nouns and their frequencies:")
for tag, frequency in sorted_nouns_following_tags.items():
    try:
        meaning = nltk.help.upenn_tagset(tag)
        print(f"Tag: {tag}, Frequency: {frequency}, Meaning: {meaning}")
    except AttributeError:
        print(f"Tag: {tag}, Frequency: {frequency}, Meaning: Not Found")
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# Tags most commonly found after nouns and their frequencies:
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# Tag: IN, Frequency: 60188, Meaning: None
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# Tag: NN, Frequency: 16824, Meaning: None
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# Tag: CC, Frequency: 16080, Meaning: None
# No matching tags found.
# Tag: NP, Frequency: 9661, Meaning: None
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# Tag: VBD, Frequency: 9229, Meaning: None
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# Tag: NNS, Frequency: 7662, Meaning: None
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# Tag: MD, Frequency: 4957, Meaning: None
# No matching tags found.
# Tag: CS, Frequency: 4942, Meaning: None
# No matching tags found.
# Tag: BEZ, Frequency: 4809, Meaning: None
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# Tag: RB, Frequency: 4694, Meaning: None
# No matching tags found.
# Tag: NN-TL, Frequency: 4165, Meaning: None
# No matching tags found.
# Tag: BEDZ, Frequency: 4018, Meaning: None
# TO: "to" as preposition or infinitive marker
#     to
# Tag: TO, Frequency: 3896, Meaning: None
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# Tag: VBN, Frequency: 3027, Meaning: None
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# Tag: VBZ, Frequency: 2912, Meaning: None
# No matching tags found.
# Tag: WPS, Frequency: 2508, Meaning: None
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# Tag: VB, Frequency: 2488, Meaning: None
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# Tag: JJ, Frequency: 2277, Meaning: None
# No matching tags found.
# Tag: BER, Frequency: 2239, Meaning: None
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# Tag: VBG, Frequency: 2150, Meaning: None
# No matching tags found.
# Tag: AT, Frequency: 1958, Meaning: None
# --: dash
#     --
# Tag: --, Frequency: 1922, Meaning: None
# No matching tags found.
# Tag: HVD, Frequency: 1801, Meaning: None
# No matching tags found.
# Tag: BED, Frequency: 1752, Meaning: None
# WDT: WH-determiner
#     that what whatever which whichever
# Tag: WDT, Frequency: 1561, Meaning: None
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# Tag: CD, Frequency: 1494, Meaning: None
# No matching tags found.
# Tag: IN-TL, Frequency: 1384, Meaning: None
# No matching tags found.
# Tag: PPS, Frequency: 1274, Meaning: None
# No matching tags found.
# Tag: HVZ, Frequency: 1242, Meaning: None
# No matching tags found.
# Tag: PPSS, Frequency: 1091, Meaning: None
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# Tag: WRB, Frequency: 1045, Meaning: None
# No matching tags found.
# Tag: QL, Frequency: 844, Meaning: None
# No matching tags found.
# Tag: HV, Frequency: 793, Meaning: None
# No matching tags found.
# Tag: CD-TL, Frequency: 637, Meaning: None
# No matching tags found.
# Tag: NP$, Frequency: 633, Meaning: None
# No matching tags found.
# Tag: NP-TL, Frequency: 565, Meaning: None
# No matching tags found.
# Tag: NNS-TL, Frequency: 477, Meaning: None
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# Tag: RP, Frequency: 468, Meaning: None
# No matching tags found.
# Tag: JJ-TL, Frequency: 433, Meaning: None
# No matching tags found.
# Tag: IN-HL, Frequency: 374, Meaning: None
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# Tag: DT, Frequency: 353, Meaning: None
# No matching tags found.
# Tag: AP, Frequency: 343, Meaning: None
# No matching tags found.
# Tag: NR, Frequency: 323, Meaning: None
# No matching tags found.
# Tag: NN-HL, Frequency: 291, Meaning: None
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# Tag: RBR, Frequency: 261, Meaning: None
# No matching tags found.
# Tag: CC-TL, Frequency: 260, Meaning: None
# No matching tags found.
# Tag: DOD, Frequency: 248, Meaning: None
# No matching tags found.
# Tag: PPL, Frequency: 230, Meaning: None
# No matching tags found.
# Tag: PP$, Frequency: 210, Meaning: None
# No matching tags found.
# Tag: BE, Frequency: 198, Meaning: None
# EX: existential there
#     there
# Tag: EX, Frequency: 156, Meaning: None
# No matching tags found.
# Tag: DOZ, Frequency: 151, Meaning: None
# No matching tags found.
# Tag: NIL, Frequency: 140, Meaning: None
# No matching tags found.
# Tag: DO, Frequency: 138, Meaning: None
# No matching tags found.
# Tag: WPO, Frequency: 132, Meaning: None
# WP$: WH-pronoun, possessive
#     whose
# Tag: WP$, Frequency: 122, Meaning: None
# No matching tags found.
# Tag: ABN, Frequency: 114, Meaning: None
# No matching tags found.
# Tag: BEG, Frequency: 106, Meaning: None
# No matching tags found.
# Tag: CD-HL, Frequency: 105, Meaning: None
# No matching tags found.
# Tag: NNS-HL, Frequency: 102, Meaning: None
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# Tag: JJR, Frequency: 100, Meaning: None
# No matching tags found.
# Tag: OD, Frequency: 96, Meaning: None
# No matching tags found.
# Tag: NP-HL, Frequency: 90, Meaning: None
# No matching tags found.
# Tag: NPS, Frequency: 83, Meaning: None
# No matching tags found.
# Tag: DTI, Frequency: 83, Meaning: None
# No matching tags found.
# Tag: CC-HL, Frequency: 82, Meaning: None
# No matching tags found.
# Tag: PN, Frequency: 75, Meaning: None
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# Tag: NN$, Frequency: 73, Meaning: None
# No matching tags found.
# Tag: AT-TL, Frequency: 67, Meaning: None
# No matching tags found.
# Tag: NN$-TL, Frequency: 63, Meaning: None
# No matching tags found.
# Tag: VBN-HL, Frequency: 60, Meaning: None
# No matching tags found.
# Tag: JJT, Frequency: 52, Meaning: None
# No matching tags found.
# Tag: DTS, Frequency: 50, Meaning: None
# No matching tags found.
# Tag: PPLS, Frequency: 47, Meaning: None
# No matching tags found.
# Tag: VBZ-HL, Frequency: 40, Meaning: None
# No matching tags found.
# Tag: ABX, Frequency: 40, Meaning: None
# No matching tags found.
# Tag: NN-TL-HL, Frequency: 38, Meaning: None
# No matching tags found.
# Tag: VBG-TL, Frequency: 37, Meaning: None
# No matching tags found.
# Tag: HVG, Frequency: 35, Meaning: None
# No matching tags found.
# Tag: BEN, Frequency: 34, Meaning: None
# No matching tags found.
# Tag: NP$-TL, Frequency: 34, Meaning: None
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# Tag: JJS, Frequency: 28, Meaning: None
# No matching tags found.
# Tag: BEZ-HL, Frequency: 25, Meaning: None
# No matching tags found.
# Tag: OD-TL, Frequency: 23, Meaning: None
# No matching tags found.
# Tag: JJ-HL, Frequency: 22, Meaning: None
# No matching tags found.
# Tag: TO-HL, Frequency: 20, Meaning: None
# No matching tags found.
# Tag: VBN-TL, Frequency: 18, Meaning: None
# No matching tags found.
# Tag: NPS-TL, Frequency: 18, Meaning: None
# No matching tags found.
# Tag: VB-TL, Frequency: 17, Meaning: None
# No matching tags found.
# Tag: PPO, Frequency: 17, Meaning: None
# No matching tags found.
# Tag: CD-TL-HL, Frequency: 17, Meaning: None
# No matching tags found.
# Tag: WQL, Frequency: 16, Meaning: None
# No matching tags found.
# Tag: VBG-HL, Frequency: 15, Meaning: None
# No matching tags found.
# Tag: ---HL, Frequency: 14, Meaning: None
# No matching tags found.
# Tag: AT-HL, Frequency: 13, Meaning: None
# No matching tags found.
# Tag: VBZ-TL, Frequency: 13, Meaning: None
# No matching tags found.
# Tag: RBT, Frequency: 13, Meaning: None
# No matching tags found.
# Tag: MD-HL, Frequency: 12, Meaning: None
# No matching tags found.
# Tag: CS-HL, Frequency: 12, Meaning: None
# No matching tags found.
# Tag: VB-HL, Frequency: 12, Meaning: None
# No matching tags found.
# Tag: NNS$-TL, Frequency: 12, Meaning: None
# No matching tags found.
# Tag: FW-JJ-TL, Frequency: 11, Meaning: None
# No matching tags found.
# Tag: FW-WDT, Frequency: 11, Meaning: None
# No matching tags found.
# Tag: FW-IN, Frequency: 10, Meaning: None
# No matching tags found.
# Tag: FW-NN-TL, Frequency: 10, Meaning: None
# No matching tags found.
# Tag: PPSS-HL, Frequency: 9, Meaning: None
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# Tag: NNS$, Frequency: 8, Meaning: None
# No matching tags found.
# Tag: RB-HL, Frequency: 8, Meaning: None
# No matching tags found.
# Tag: JJ-NC, Frequency: 8, Meaning: None
# No matching tags found.
# Tag: RP-HL, Frequency: 7, Meaning: None
# No matching tags found.
# Tag: FW-NN, Frequency: 7, Meaning: None
# No matching tags found.
# Tag: NR-TL, Frequency: 7, Meaning: None
# No matching tags found.
# Tag: NN-NC, Frequency: 7, Meaning: None
# No matching tags found.
# Tag: AT-NC, Frequency: 7, Meaning: None
# No matching tags found.
# Tag: IN-NC, Frequency: 7, Meaning: None
# No matching tags found.
# Tag: NNS-TL-HL, Frequency: 6, Meaning: None
# No matching tags found.
# Tag: IN-TL-HL, Frequency: 6, Meaning: None
# No matching tags found.
# Tag: TO-TL, Frequency: 6, Meaning: None
# No matching tags found.
# Tag: VBD-HL, Frequency: 5, Meaning: None
# No matching tags found.
# Tag: RB-TL, Frequency: 5, Meaning: None
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# Tag: UH, Frequency: 5, Meaning: None
# No matching tags found.
# Tag: ABL, Frequency: 5, Meaning: None
# No matching tags found.
# Tag: BEZ-TL, Frequency: 5, Meaning: None
# No matching tags found.
# Tag: FW-CC, Frequency: 5, Meaning: None
# No matching tags found.
# Tag: RB-NC, Frequency: 5, Meaning: None
# No matching tags found.
# Tag: NPS$, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: FW-IN-TL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: JJ-TL-HL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: NP$-HL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: FW-AT-TL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: BER-TL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: QLP, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: WPS-TL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: BE-HL, Frequency: 4, Meaning: None
# No matching tags found.
# Tag: BER-HL, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: DO-HL, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: AP-HL, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: WRB-HL, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: NPS-HL, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: FW-NNS, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: HVZ-TL, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: DTX, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: TO-NC, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: PPSS-NC, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: NNS-NC, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: BER-NC, Frequency: 3, Meaning: None
# No matching tags found.
# Tag: JJR-HL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: MD-TL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: QL-TL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: FW-NNS-TL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: CC-TL-HL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: FW-JJ, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: VBN-TL-HL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: HV-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: VB-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: VBD-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: RP-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: VBZ-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: MD-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: CS-NC, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: WPS-HL, Frequency: 2, Meaning: None
# No matching tags found.
# Tag: JJT-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: BEDZ-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: NR-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: NPS$-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: DOZ-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: NN$-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: PPL-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: BE-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: VBD-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: PPO-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: PP$-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: JJS-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: CS-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-NN-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: AP-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-RB, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: JJT-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: UH-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: PPSS-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: DT-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-VBG-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: HV-HL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-NNS-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: VBN-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: HVZ-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: CD-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: QL-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: OD-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: BEZ-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: WPS-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: PP$-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: DOD-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: WPO-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: WDT-NC, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: BEM, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-VB, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-CC-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: PN-TL, Frequency: 1, Meaning: None
# No matching tags found.
# Tag: FW-NP-TL, Frequency: 1, Meaning: None
